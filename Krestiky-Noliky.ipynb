# %%
K=[["_","_","_"],["_","_","_"],["_","_","_"]]
def func(i,j,a,L):
    M=L.pop(i)
    M.pop(j)
    M.insert(j,a)
    L.insert(i,M)
    final_string=""
    counter=0
    for x in L:
        string="_".join(x)
        final_string=final_string+str(counter)+string+"\n"
        counter+=1
    print(" 0 1 2")
    print(final_string)
    return L

print("Вот наше игральное поле:")
func(1,1,"_",K)
while True:
    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
# print(list1)
#     K=func(list1[1],list1[0],"X",K)
# print(K)
    if list1==[0,0]:
        K=func(list1[1],list1[0],"X",K)
        K=func(1,1,"0",K)
        while True:
            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
            if list1==[1,0]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,2,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(1,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,1,"0",K)
                                print("Ничья")
                                break
                            elif list1==[1,2] or list1==[2,2]:
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,1] or list1==[2,1] or list1==[1,2] or list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,0,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[2,0]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,1,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(1,0,"0",K)
                        while True:
                                list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                                if list1==[2,1]:
                                    K=func(list1[1],list1[0],"X",K)
                                    K=func(2,0,"0",K)
                                    print("Ничья")
                                    break
                                elif list1==[0,2] or list1==[2,2]:
                                    K=func(list1[1],list1[0],"X",K)
                                    K=func(1,2,"0",K)
                                    print("Выиграл компьютер")
                                    break
                                else:
                                    print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,1] or list1==[2,1] or list1==[0,2] or list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,1,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[0,1]:
                K=func(list1[1],list1[0],"X",K)
                K=func(2,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,0]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,1,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,2,"0",K)
                                print("Ничья")
                                break
                            elif list1==[2,1] or list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,1,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[1,0] or list1==[2,1] or list1==[1,2] or list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[2,1]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,2,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(1,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,0] or list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,2,"0",K)
                                print("Ничья")
                            elif list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,1,"0",K)
                                print("Ничья")  
                        break
                    elif list1==[1,0] or list1==[0,1] or list1==[1,2] or list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,0,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[0,2]:
                K=func(list1[1],list1[0],"X",K)
                K=func(1,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,1]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,1,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,2,"0",K)
                                print("Ничья")
                                break
                            elif list1==[2,0] or list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,1,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[1,0] or list1==[2,0] or list1==[1,2] or list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(1,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[1,2]:
                K=func(list1[1],list1[0],"X",K)
                K=func(1,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,1]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,2,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[0,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,1,"0",K)
                                print("Ничья")
                                break
                            elif list1==[1,0] or list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[1,0] or list1==[2,0] or list1==[0,2] or list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(1,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[2,2]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,1,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[1,2]:
                        
                        break
                    elif list1==[2,0] or list1==[0,1] or list1==[2,1] or list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,1,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            else:
                print("Вы ввели неверные координаты")
        break 
    elif list1==[0,1]:
        K=func(list1[1],list1[0],"X",K)
        K=func(1,1,"0",K)
        while True:
            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
            if list1==[0,0]:
                K=func(list1[1],list1[0],"X",K)
                K=func(2,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,0]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,1,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,2]:
                                break
                            elif list1==[2,1] or list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,1,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[1,0] or list1==[2,1] or list1==[1,2] or list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[1,0]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,2,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,2,"0",K)
                                print("Ничья")
                                break
                            elif list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,2,"0",K)
                                print("Ничья")
                                break
                            elif list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,1,"0",K)
                                print("Ничья")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,0] or list1==[2,1] or list1==[1,2] or list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,0,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[2,0]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,1,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,2,"0",K)
                                print("Ничья")
                                break
                            elif list1==[2,1] or list1==[0,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,2,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,0] or list1==[2,1] or list1==[0,2] or list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,1,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[2,1]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,1,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,2,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[0,0] or list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            elif list1==[0,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,0] or list1==[2,0] or list1==[0,2] or list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,1,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[0,2]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,1,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,2,"0",K)
                                print("Ничья")
                                break
                            elif list1==[2,0] or list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,1,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[1,0] or list1==[2,0] or list1==[2,1] or list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[1,2]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,0] or list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,2,"0",K)
                                print("Выиграл компьютер")
                                break
                            elif list1==[2,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,1,"0",K)
                                print("Ничья")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[1,0] or list1==[2,0] or list1==[2,1] or list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[2,2]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,1,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[2,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,1,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,0] or list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,2,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,0] or list1==[2,0] or list1==[2,1] or list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,1,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            else:
                print("Вы ввели неверные координаты")
        break
    elif list1==[0,2]: 
        K=func(list1[1],list1[0],"X",K)
        K=func(1,1,"0",K)
        while True:
            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
            if list1==[0,0]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,1,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(1,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,2] or list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,2,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,1] or list1==[2,1] or list1==[0,2] or list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,1,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[1,0]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(1,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            elif list1==[0,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,2,"0",K)
                                print("Выиграл компьютер")
                                break
                            elif list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,2,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,1] or list1==[2,1] or list1==[0,2] or list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[0,1]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,1,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[2,1] or list1==[0,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,2,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,0] or list1==[2,1] or list1==[0,2] or list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,1,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[2,1]:
                K=func(list1[1],list1[0],"X",K)
                K=func(2,2,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[0,0]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,1,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,1] or list1==[0,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,1,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[1,0] or list1==[0,1] or list1==[0,2] or list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,0,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[0,2]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,1,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,2,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[0,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,1] or list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,0] or list1==[0,1] or list1==[2,1] or list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,1,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[1,2]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[0,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,1,"0",K)
                                print("Ничья")
                                break
                            elif list1==[1,0] or list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[1,0] or list1==[0,1] or list1==[2,1] or list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[2,2]:
                K=func(list1[1],list1[0],"X",K)
                K=func(1,2,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[0,1]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,1,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,0] or list1==[0,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,1,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,0] or list1==[1,0] or list1==[0,2] or list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(1,0,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            else:
                print("Вы ввели неверные координаты")
        break
    elif list1==[1,0]:
        K=func(list1[1],list1[0],"X",K)
        K=func(1,1,"0",K)
        while True:
            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
            if list1==[0,0]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,2,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(1,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,2,"0",K)
                                print("Ничья")
                                break
                            elif list1==[1,2] or list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,2,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,1] or list1==[2,1] or list1==[1,2] or list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,0,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[2,0]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(1,2,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[0,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,2] or list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,1] or list1==[2,1] or list1==[0,2] or list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[0,1]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,2,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[0,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,1,"0",K)
                                print("Ничья")
                                break
                            elif list1==[2,1] or list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[2,0] or list1==[2,1] or list1==[0,2] or list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[2,1]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,2]:
                        break
                    elif list1==[2,0] or list1==[0,1] or list1==[0,2] or list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,2,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[0,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,1,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,1] or list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[0,2]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,1,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,2,"0",K)
                                print("Ничья")
                                break
                            elif list1==[2,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,2,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,2,"0",K)
                                print("Ничья")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[2,0] or list1==[0,1] or list1==[2,1] or list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[1,2]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[0,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,2,"0",K)
                                print("Ничья")
                                break
                            elif list1==[2,0] or list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[2,0] or list1==[0,1] or list1==[2,1] or list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[2,2]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,2,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(1,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,0] or list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,2,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,0] or list1==[0,1] or list1==[2,1] or list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,0,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            else:
                print("Вы ввели неверные координаты")
        break
    elif list1==[1,2]:
        K=func(list1[1],list1[0],"X",K)
        K=func(1,1,"0",K)
        while True:
            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
            if list1==[0,0]:
                K=func(list1[1],list1[0],"X",K)
                K=func(1,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,1]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,2,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split())) 
                            if list1==[0,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,2,"0",K)
                                print("Ничья")
                                break
                            elif list1==[1,0] or list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[1,0] or list1==[2,0] or list1==[0,2] or list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(1,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[1,0]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[0,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,2,"0",K)
                                print("Выиграл компьютер")
                                break
                            elif list1==[2,0] or list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[2,0] or list1==[0,1] or list1==[2,1] or list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[2,0]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[0,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,1,"0",K)
                                print("Ничья")
                                break
                            elif list1==[1,0] or list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[1,0] or list1==[0,1] or list1==[2,1] or list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[0,1]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[2,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,1,"0",K)
                                print("Ничья")
                                break
                            elif list1==[1,0] or list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,2,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[1,0] or list1==[2,0] or list1==[2,1] or list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[2,1]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[0,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,2,"0",K)
                                print("Выиграл компьютер")
                                break
                            elif list1==[1,0] or list1==[2,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[1,0] or list1==[2,0] or list1==[0,1] or list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[0,2]:
                K=func(list1[1],list1[0],"X",K)
                K=func(2,2,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[0,0]:
                        break
                    elif list1==[1,0] or list1==[2,0] or list1==[0,1] or list1==[2,1]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(1,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,1,"0",K)
                                print("Ничья")
                                break
                            elif list1==[1,0] or list1==[2,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,2,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[2,2]:
                K=func(list1[1],list1[0],"X",K)
                K=func(2,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,0]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(1,2,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[0,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,0] or list1==[1,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,0] or list1==[1,0] or list1==[0,1] or list1==[2,1]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            else:
                print("Вы ввели неверные координаты")
        break
    elif list1==[2,0]:
        K=func(list1[1],list1[0],"X",K)
        K=func(1,1,"0",K)
        while True:
            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
            if list1==[0,0]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,1,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[1,2]:
                        break
                    elif list1==[0,1] or list1==[2,1] or list1==[0,2] or list1==[1,2] or list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(1,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,2,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,2] or list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,2,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[1,0]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(1,2,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[0,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,2] or list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,1] or list1==[2,1] or list1==[0,2] or list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты") 
                break
            elif list1==[0,2]: 
                K=func(list1[1],list1[0],"X",K)
                K=func(0,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split())) 
                    if list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(1,2,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split())) 
                            if list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K)
                                print("Вы выиграли")
                                break
                            elif list1==[1,0] or list1==[0,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,1,"0",K)
                                print("Ничья")
                                break
                            else:
                                print("Вы ввели неверные координаты")             
                        break
                    elif list1==[1,0] or list1==[0,1] or list1==[2,1] or list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[0,1]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(1,2,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,1,"0",K)
                                print("Ничья")
                                break
                            elif list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,0,"0",K)
                                print("Ничья")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[1,0] or list1==[2,1] or list1==[0,2] or list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[2,1]:
                K=func(list1[1],list1[0],"X",K)
                K=func(2,2,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[0,0]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,1,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,1] or list1==[0,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,1,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[1,0] or list1==[0,1] or list1==[0,2] or list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,0,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[1,2]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,1,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[0,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,1,"0",K)
                                print("Ничья")
                                break
                            elif list1==[1,0] or list1==[0,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты") 
                        break
                    elif list1==[1,0] or list1==[0,1] or list1==[2,1] or list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[2,2]:
                K=func(list1[1],list1[0],"X",K)
                K=func(1,2,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[0,1]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,1,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,0] or list1==[0,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,1,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,0] or list1==[1,0] or list1==[0,2] or list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(1,0,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            else:
                print("Вы ввели неверные координаты")
        break
    elif list1==[2,1]:
        K=func(list1[1],list1[0],"X",K)
        K=func(1,1,"0",K)
        while True:
            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
            if list1==[0,0]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,1,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,2,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[0,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,1] or list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[2,0] or list1==[0,1] or list1==[0,2] or list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,1,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[1,0]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,2,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[0,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,1,"0",K)
                                print("Ничья")
                                break
                            elif list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,0,"0",K)
                                print("Ничья")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[2,0] or list1==[0,1] or list1==[0,2] or list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[2,0]:
                K=func(list1[1],list1[0],"X",K)
                K=func(2,2,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[0,0]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,1,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,1] or list1==[0,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,1,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[1,0] or list1==[0,1] or list1==[0,2] or list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,0,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[0,1]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,2,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            elif list1==[0,2] or list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,1,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[1,0] or list1==[2,0] or list1==[0,2] or list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[0,2]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,2,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K)
                                print("Вы выиграли")
                                break
                            elif list1==[1,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,1,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,1,"0",K)
                                print("Ничья")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[1,0] or list1==[2,0] or list1==[0,1] or list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[1,2]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,2,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,2]:
                                K=func(list1[1],list1[0],"X",K)
                                print("Вы выиграли")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[1,0] or list1==[2,0] or list1==[0,1] or list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[2,2]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,2,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,1,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,0] or list1==[0,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,1,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,0] or list1==[1,0] or list1==[0,1] or list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,0,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            else:
                print("Вы ввели неверные координаты")
        break
    elif list1==[2,2]:
        K=func(list1[1],list1[0],"X",K)
        K=func(1,1,"0",K)
        while True:
            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
            if list1==[0,0]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,2,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(1,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K)
                                print("Вы выиграли")
                                break
                            elif list1==[1,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,2,"0",K)
                                print("Выиграл компьютер")
                                break
                            elif list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,1,"0",K)
                                print("Ничья")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[1,0] or list1==[0,1] or list1==[2,1] or list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,0,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[1,0]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,2,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,1,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[0,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,0,"0",K)
                                print("Ничья")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,0] or list1==[0,1] or list1==[2,1] or list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,0,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[2,0]:
                K=func(list1[1],list1[0],"X",K)
                K=func(1,2,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[0,1]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,1,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,0] or list1==[0,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,1,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,0] or list1==[1,0] or list1==[0,2] or list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(1,0,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[0,1]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,2,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,2,"0",K)
                                print("Выиграл компьютер")
                                break
                            elif list1==[1,2] or list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,1,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,0] or list1==[1,0] or list1==[1,2] or list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,0,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[2,1]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,2,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,1,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,0] or list1==[0,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,1,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,0] or list1==[1,0] or list1==[0,1] or list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,0,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[0,2]:
                K=func(list1[1],list1[0],"X",K)
                K=func(2,1,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[1,0]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(1,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,0] or list1==[2,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,2,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,0] or list1==[2,0] or list1==[0,1] or list1==[2,1]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,1,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[1,2]:
                K=func(list1[1],list1[0],"X",K)
                K=func(2,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,0]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(1,2,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[0,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,0] or list1==[1,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,0] or list1==[1,0] or list1==[0,1] or list1==[2,1]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            else:
                print("Вы ввели неверные координаты")
        break
    elif list1==[1,1]:
        K=func(list1[1],list1[0],"X",K)
        K=func(0,0,"0",K)
        while True:
            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
            if list1==[1,0]:
                K=func(list1[1],list1[0],"X",K)
                K=func(2,1,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,0]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[0,1]:
                                K=func(list1[1],list1[0],"X",K)
                                print("Ничья")
                                break
                            elif list1==[2,1] or list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,1]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(1,2,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[2,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,2,"0",K)
                                print("Ничья")
                                break
                            elif list1==[2,2]:
                                print("Ничья")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[2,1]:
                        K=func(list1[1],list1[0],"X",K)
                        K=(1,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[2,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            elif list1==[0,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(0,2,"0",K)
                                print("Ничья")
                                break
                            elif list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(2,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:    
                                print("Вы ввели неверные координаты")  
                        break
                    elif list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=(0,2,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[0,1]:
                                K=func(list1[1],list1[0],"X",K) 
                                K=func(1,2,"0",K)
                                print("Ничья")
                                break
                            if list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K) 
                                K=func(1,0,"0",K)
                                print("Ничья")
                                break
                            if list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K) 
                                print("Ничья")
                                break
                        break
                    elif list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=(1,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[0,2]:
                                print("Ничья")
                                break
                            elif list1==[0,2] or list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K) 
                                K=func(2,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы неверно ввели координаты")
                        break
                    else:
                        print("Вы неверно ввели координаты")
                break
            elif list1==[2,0]:
                K=func(list1[1],list1[0],"X",K)
                K=func(2,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[0,1]:
                        K=func(list1[1],list1[0],"X",K) 
                        K=func(1,2,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,0]:
                                K=func(list1[1],list1[0],"X",K) 
                                K=func(2,1,"0",K)
                                print("Ничья")
                                break
                            elif list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K) 
                                K=func(0,1,"0",K)
                                print("Ничья")
                                break 
                            elif list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K) 
                                print("Ничья")
                                break 
                    elif list1==[1,0] or list1==[2,1] or list1==[1,2] or list1==[2,2]:
                        K=func(1,0,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[0,1]:
                K=func(list1[1],list1[0],"X",K)
                K=(1,2,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[1,0]:
                        K=func(list1[1],list1[0],"X",K) 
                        K=func(2,1,"0",K)
                        print("Ничья")
                        break
                    elif list1==[2,0]:
                        K=func(list1[1],list1[0],"X",K) 
                        K=func(2,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,0]:
                                K=func(list1[1],list1[0],"X",K) 
                                K=func(2,1,"0",K)
                                print("Ничья")
                                break
                            elif list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K) 
                                K=func(0,1,"0",K)
                                print("Ничья")
                                break
                            elif list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K) 
                                K=func(0,1,"0",K)
                                print("Ничья")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K) 
                        K=func(0,2,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,0]:
                                K=func(list1[1],list1[0],"X",K) 
                                K=func(2,1,"0",K)
                                print("Ничья")
                                break
                            elif list1==[1,2] or list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K) 
                                K=func(0,1,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K) 
                        K=func(0,1,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[2,0]:
                                K=func(list1[1],list1[0],"X",K) 
                                K=func(2,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,2]:
                                K=func(list1[1],list1[0],"X",K) 
                                K=func(2,2,"0",K)
                                print("Вы выиграли")
                                break
                            elif list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K) 
                                K=func(2,0,"0",K)
                                print("Ничья")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K) 
                        K=func(0,1,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[2,0]:
                                K=func(list1[1],list1[0],"X",K) 
                                K=func(2,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,2] or list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K) 
                                K=func(0,2,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[2,1]:
                K=func(list1[1],list1[0],"X",K)
                K=func(1,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K) 
                        K=func(0,2,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,0]:
                                K=func(list1[1],list1[0],"X",K) 
                                K=func(0,2,"0",K)
                                print("Ничья")
                                break
                            elif list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K) 
                                K=func(0,1,"0",K)
                                print("Ничья")
                                break
                            elif list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K) 
                                K=func(2,1,"0",K)
                                print("Ничья")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    if list1==[1,0] or list1==[2,0] or list1==[1,2] or list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K) 
                        K=func(2,0,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[0,2]:
                K=func(list1[1],list1[0],"X",K)
                K=func(0,2,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[1,0]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(2,1,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[0,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,2,"0",K)
                                print("Ничья")
                                break
                            elif list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[2,2]:  
                                K=func(list1[1],list1[0],"X",K)
                                K=func(1,0,"0",K)
                                print("Ничья")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,1] or list1==[2,1] or list1==[1,2] or list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=func(0,1,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы ввели неверные координаты")
                break
            elif list1==[1,2]:
                K=func(list1[1],list1[0],"X",K)
                K=(0,1,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[2,0]:
                        K=func(list1[1],list1[0],"X",K)
                        K=(2,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[0,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=(1,2,"0",K)
                                print("Ничья")
                                break
                            elif list1==[2,1] or list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=(1,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,1]:
                        K=func(list1[1],list1[0],"X",K)
                        K=(1,2,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[2,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=(2,0,"0",K)
                                print("Ничья")
                                break
                            elif list1==[0,2] or list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=(0,2,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[2,1]:
                        K=func(list1[1],list1[0],"X",K)
                        K=(1,0,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[2,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=(2,0,"0",K)
                                print("Выиграл компьютер")
                                break
                            elif list1==[0,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=(0,2,"0",K)
                                print("Выиграл компьютер")
                                break
                            elif list1==[2,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=(0,2,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы ввели неверные координаты")
                        break
                    elif list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=(0,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    elif list1==[2,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=(0,2,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы неверно ввели координаты")
                break
            elif list1==[2,2]:
                K=func(list1[1],list1[0],"X",K)
                K=(1,0,"0",K)
                while True:
                    list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                    if list1==[0,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=(0,2,"0",K)
                        while True:
                            list1=list(map(int,input("Введите ваш ход: координаты по горизонтали и по вертикали через пробел").split()))
                            if list1==[1,0]:
                                K=func(list1[1],list1[0],"X",K)
                                K=(2,1,"0",K)
                                print("Ничья")
                                break
                            elif list1==[2,1]:
                                K=func(list1[1],list1[0],"X",K)
                                K=(0,1,"0",K)
                                print("Выиграл компьютер")
                                break
                            elif list1==[1,2]:
                                K=func(list1[1],list1[0],"X",K)
                                K=(0,1,"0",K)
                                print("Выиграл компьютер")
                                break
                            else:
                                print("Вы неверно ввели координаты")
                        break
                    elif list1==[1,0] or list1==[2,0] or list1==[2,1] or list1==[1,2]:
                        K=func(list1[1],list1[0],"X",K)
                        K=(2,0,"0",K)
                        print("Выиграл компьютер")
                        break
                    else:
                        print("Вы неверно ввели координаты")
            else:
                print("Вы неверно ввели координаты")
        break
    else:
        print("Вы неверно ввели координаты")
# Out:
# Вот наше игральное поле:
#  0 1 2
# 0_____
# 1_____
# 2_____
#
# Введите ваш ход: координаты по горизонтали и по вертикали через пробел1 1
#  0 1 2
# 0_____
# 1__X__
# 2_____
#
#  0 1 2
# 00____
# 1__X__
# 2_____
#
# Введите ваш ход: координаты по горизонтали и по вертикали через пробел1 0
#  0 1 2
# 00_X__
# 1__X__
# 2_____
#
#  0 1 2
# 00_X__
# 1__X__
# 2__0__
#
# Введите ваш ход: координаты по горизонтали и по вертикали через пробел2 0
#  0 1 2
# 00_X_X
# 1__X__
# 2__0__
#
#  0 1 2
# 00_X_X
# 1__X__
# 20_0__
#
# Введите ваш ход: координаты по горизонтали и по вертикали через пробел0 1
#  0 1 2
# 00_X_X
# 1X_X__
# 20_0__
#
# Ничья
